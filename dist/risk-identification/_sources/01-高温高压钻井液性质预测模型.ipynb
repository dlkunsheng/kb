% %% [markdown]
% # 01-高温高压钻井液性质预测模型

% %% [markdown]
% ###    第一个模型  Sorelle – 1982

% %%
close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
    
    % 第1个模型（Sorelle – 1982）
    [result_01] = Function_ParameterSol01(Data); % 第1个模型参数计算结果
    rc_01=size(result_01);
    row_01=rc_01(1,1); % 第1个模型参数计算结果构成的列向量有几行
    for j=1:1:row_01
        RESULT(j,i)=result_01(j,1); % 将第1个模型参数计算结果存储到RESULT中
    end
end
RESULT
% Out:
% RESULT = 7x9 double
%    42.7000   50.3000   42.7000   42.7000   42.7000   50.3000   42.7000   42.7000   42.7000
%    30.9000   30.2000   30.9000   30.9000   30.9000   30.2000   30.9000   30.9000   30.9000
%     3.2342    0.0576    0.6607    0.5916    0.7866    0.0474    1.2983    0.8547    0.1706
%    -0.0339   -0.0007    0.0012   -0.0081   -0.0105   -0.0005   -0.0199   -0.0000   -0.0016
%     0.0131    0.0004   -0.0006    0.0043    0.0049    0.0003    0.0122    0.0006    0.0005
%     0.8545    0.8454    0.2520    0.7451    0.6897    0.7814    0.6253    0.4768    0.8497
%    13.8369    7.8807    4.4058   22.1643   31.0654    8.8896   28.1683    2.3520   13.6541

% %% [markdown]
% ### 第二个模型 Politte – 1985

% %%
close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
     [result_02] = Function_ParameterSol02(Data); % 第2个模型参数计算结果
    rc_02=size(result_02);
    row_02=rc_02(1,1); % 第2个模型参数计算结果构成的列向量有几行
    for j=1:1:row_02
        RESULT(j,i)=result_02(j,1); % 将第2个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01,i)=result_02(j,1); % 将第2个模型参数计算结果存储到RESULT中
    end
end
RESULT
% Out:
% RESULT = 10x9 double
%    50.3000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.2000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     3.4245    0.0789    0.6532    0.6903    0.9035    0.0646    1.5100    0.8564    0.2007
%    -0.0645   -0.0017    0.0016   -0.0188   -0.0216   -0.0013   -0.0474   -0.0016   -0.0024
%     0.0002    0.0000    0.0000    0.0002    0.0001    0.0000    0.0004    0.0000    0.0000
%     0.0230    0.0010   -0.0010    0.0115    0.0129    0.0007    0.0355    0.0027   -0.0002
%    -0.0001    0.0000    0.0000    0.0000   -0.0000    0.0000   -0.0001   -0.0000    0.0000
%     0.0001   -0.0000   -0.0000   -0.0001   -0.0001   -0.0000   -0.0003   -0.0000    0.0000
%     0.9321    0.9494    0.3012    0.8598    0.7513    0.8933    0.8028    0.7339    0.9447
%     8.3722    5.9527    4.7896   19.0014   32.4343    8.1743   25.3099    1.5612    7.8129

% %% [markdown]
% ### 第三个模型 Minton – 1988

% %%
close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
     [result_03] = Function_ParameterSol03(Data); % 第3个模型参数计算结果
    rc_03=size(result_03);
    row_03=rc_03(1,1); % 第3个模型参数计算结果构成的列向量有几行
    for j=1:1:row_03
        RESULT(j,i)=result_03(j,1); % 将第3个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02,i)=result_03(j,1); % 将第3个模型参数计算结果存储到RESULT中
    end
end
RESULT
% Out:
% RESULT = 7x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     2.8930    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%    -0.0140   -0.0197    0.0003   -0.0180   -0.0154   -0.0199   -0.0196   -0.0006   -0.0161
%     0.0058    0.0107    0.0000    0.0074    0.0040    0.0113    0.0098    0.0010    0.0053
%     0.9326    0.9702    0.0740    0.9306    0.8695    0.9618    0.8441    0.4762    0.9733
%    13.2819   10.1748    5.3547   17.3295   28.2758   11.3797   25.8375    2.4421   10.2104

% %% [markdown]
% ### 第四个模型 Fisk – 1989

% %%
close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
       [result_04] = Function_ParameterSol04(Data); % 第4个模型参数计算结果
    rc_04=size(result_04);
    row_04=rc_04(1,1); % 第4个模型参数计算结果构成的列向量有几行
    for j=1:1:row_04
        RESULT(j,i)=result_04(j,1); % 将第4个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03,i)=result_04(j,1); % 将第4个模型参数计算结果存储到RESULT中
    end
    end
    RESULT
% Out:
% RESULT = 6x9 double
%     3.2630    0.0630    0.7010    0.4920    0.6950    0.0530    0.8870    0.8810    0.2020
%     0.1082    0.1383    1.0167    0.1013    0.0969    0.1567    0.1229    0.9345    0.1127
%   122.8967  101.3843   -3.9471  131.7110  134.8077   93.0421  125.4229    0.7432  113.7476
%     0.0036    0.0062    0.0003    0.0046    0.0024    0.0059    0.0056    0.0008    0.0025
%     0.8021    0.6970    0.1694    0.5905    0.5709    0.6165    0.3984    0.4809    0.8509
%    13.5294   10.4071    4.9482   21.7171   28.4359   10.8963   29.5999    2.3750   12.3055

% %% [markdown]
% ### 第五个模型 鄢捷年 – 1990

% %%
close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
[result_05] = Function_ParameterSol05(Data); % 第5个模型参数计算结果
    rc_05=size(result_05);
    row_05=rc_05(1,1); % 第5个模型参数计算结果构成的列向量有几行
    for j=1:1:row_05
        RESULT(j,i)=result_05(j,1); % 将第5个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04,i)=result_05(j,1); % 将第5个模型参数计算结果存储到RESULT中
    end
    end
    RESULT
% Out:
% RESULT = 8x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     2.8930    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%    -0.0135   -0.0204   -0.0000   -0.0184   -0.0157   -0.0200   -0.0195   -0.0006   -0.0167
%     0.0078    0.0068   -0.0010    0.0044    0.0016    0.0061    0.0104    0.0009    0.0033
%    -0.0000    0.0001    0.0000    0.0000    0.0000    0.0001   -0.0000    0.0000    0.0000
%     0.9367    0.9787    0.1767    0.9342    0.8714    0.9678    0.8442    0.4768    0.9766
%    14.9678   17.3575    6.2563   20.2459   30.0612   20.1661   25.7013    2.4474   13.3992

% %% [markdown]
% ### 第六个模型 Eirik – 1998

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
 [result_06] = Function_ParameterSol06(Data); % 第6个模型参数计算结果
    rc_06=size(result_06);
    row_06=rc_06(1,1); % 第6个模型参数计算结果构成的列向量有几行
    for j=1:1:row_06
        RESULT(j,i)=result_06(j,1); % 将第6个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05,i)=result_06(j,1); % 将第6个模型参数计算结果存储到RESULT中
    end
    end
    RESULT
% Out:
% RESULT = 10x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     2.8930    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%    -0.0101   -0.0326    0.0001   -0.0203   -0.0008   -0.0336   -0.0282   -0.0027   -0.0125
%    -0.0001    0.0002    0.0000   -0.0001   -0.0006    0.0003   -0.0001    0.0000   -0.0000
%     0.0051    0.0199   -0.0015    0.0109   -0.0071    0.0208    0.0213    0.0031   -0.0027
%    -0.0001    0.0000    0.0000   -0.0002   -0.0004    0.0001   -0.0003   -0.0000    0.0001
%     0.0001   -0.0002   -0.0000    0.0004    0.0010   -0.0003    0.0004   -0.0000   -0.0000
%     0.9382    0.9926    0.2155    0.9362    0.8684    0.9842    0.9118    0.7198    0.9853
%    12.7405    4.9823    5.0005   16.8353   26.5926    7.2011   19.9505    1.6826    7.4211

% %% [markdown]
% ### 第七个模型 周福建 – 1999

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
      [result_07] = Function_ParameterSol07(Data); % 第7个模型参数计算结果
    rc_07=size(result_07);
    row_07=rc_07(1,1); % 第7个模型参数计算结果构成的列向量有几行
    for j=1:1:row_07
        RESULT(j,i)=result_07(j,1); % 将第7个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06,i)=result_07(j,1); % 将第7个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 8x9 double
%    50.3000   50.3000   42.7000   42.7000   42.7000   50.3000   42.7000   42.7000   42.7000
%    30.2000   30.2000   30.9000   30.9000   30.9000   30.2000   30.9000   30.9000   30.9000
%     3.2630    0.0630    0.7010    0.5840    0.6770    0.0530    1.2800    0.8810    0.1880
%     0.9645    0.9124    0.9423    1.0255    1.1170    0.8932    0.9945    0.9697    0.9889
%    -0.0179   -0.0146    0.0018   -0.0191   -0.0175   -0.0135   -0.0195   -0.0000   -0.0159
%     0.0069    0.0089   -0.0008    0.0083    0.0048    0.0085    0.0098    0.0007    0.0053
%     0.8687    0.8831    0.2555    0.7111    0.6196    0.7992    0.5191    0.4790    0.8723
%    10.0829    6.5041    4.3856   17.9691   27.6115    8.2227   25.8276    2.3713   10.1709

% %% [markdown]
% ### 第八个模型 汪海阁 – 2000

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
      [result_08] = Function_ParameterSol08(Data); % 第8个模型参数计算结果
    rc_08=size(result_08);
    row_08=rc_08(1,1); % 第8个模型参数计算结果构成的列向量有几行
    for j=1:1:row_08
        RESULT(j,i)=result_08(j,1); % 将第8个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07,i)=result_08(j,1); % 将第8个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 8x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     2.8930    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%    -0.0118   -0.0242   -0.0003   -0.0212   -0.0172   -0.0240   -0.0213   -0.0011   -0.0179
%     0.0061    0.0096   -0.0008    0.0065    0.0035    0.0094    0.0095    0.0008    0.0047
%    -0.0000    0.0001    0.0000    0.0000    0.0000    0.0001    0.0000    0.0000    0.0000
%     0.9373    0.9857    0.1804    0.9370    0.8714    0.9738    0.8462    0.4552    0.9781
%    12.8295    6.9405    4.6371   16.4054   28.0055    9.3216   25.5379    2.4898    9.4413

% %% [markdown]
% ### 第九个模型 张琰 – 2000

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
      [result_09] = Function_ParameterSol09(Data); % 第9个模型参数计算结果
    rc_09=size(result_09);
    row_09=rc_09(1,1); % 第9个模型参数计算结果构成的列向量有几行
    for j=1:1:row_09
        RESULT(j,i)=result_09(j,1); % 将第9个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07+row_08,i)=result_09(j,1); % 将第9个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 7x9 double
%    50.3000   50.3000   42.7000   42.7000   42.7000   50.3000   42.7000   42.7000   42.7000
%    30.2000   30.2000   30.9000   30.9000   30.9000   30.2000   30.9000   30.9000   30.9000
%     1.1465   -2.8563   -0.4147   -0.5127   -0.2794   -3.0504    0.2414   -0.1575   -1.6824
%    -0.0179   -0.0146    0.0018   -0.0191   -0.0175   -0.0135   -0.0195   -0.0000   -0.0159
%     0.0069    0.0089   -0.0008    0.0083    0.0048    0.0085    0.0098    0.0007    0.0053
%     0.8687    0.8831    0.2555    0.7111    0.6196    0.7992    0.5191    0.4790    0.8723
%    10.0829    6.5041    4.3856   17.9691   27.6115    8.2227   25.8276    2.3713   10.1709

% %% [markdown]
% ### 第十个模型 赵胜英 – 2009

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
    [result_10] = Function_ParameterSol10(Data); % 第10个模型参数计算结果
    rc_10=size(result_10);
    row_10=rc_10(1,1); % 第10个模型参数计算结果构成的列向量有几行
    for j=1:1:row_10
        RESULT(j,i)=result_10(j,1); % 将第10个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07+row_08+row_09,i)=result_10(j,1); % 将第10个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 9x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     2.8930    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%    -0.0117   -0.0309    0.0010   -0.0301   -0.0163   -0.0304   -0.0427   -0.0030   -0.0106
%    -0.0000    0.0002   -0.0000    0.0002    0.0000    0.0002    0.0004    0.0000   -0.0001
%     0.0060    0.0186   -0.0020    0.0186    0.0023    0.0182    0.0327    0.0033   -0.0038
%     0.0000   -0.0001    0.0000   -0.0002    0.0000   -0.0001   -0.0004   -0.0000    0.0001
%     0.9373    0.9922    0.1920    0.9329    0.8715    0.9827    0.9123    0.7124    0.9845
%    12.8217    5.2054    5.0447   18.1731   27.8267    7.5756   20.4695    1.7286    7.6534

% %% [markdown]
% ### 第十一个模型 Zamora – 2013

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
    [result_11] = Function_ParameterSol11(Data); % 第11个模型参数计算结果
    rc_11=size(result_11);
    row_11=rc_11(1,1); % 第11个模型参数计算结果构成的列向量有几行
    for j=1:1:row_11
        RESULT(j,i)=result_11(j,1); % 将第11个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07+row_08+row_09+row_10,i)=result_11(j,1); % 将第11个模型参数计算结果存储到RESULT中
    end
    
    end
RESULT
% Out:
% RESULT = 10x9 double
%    42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     3.3775    0.0762    0.6723    0.6179    0.8032    0.0632    1.3272    0.8589    0.2022
%     0.0329    0.0004   -0.0031    0.0112    0.0185    0.0002    0.0419    0.0018   -0.0005
%    -0.0004   -0.0000    0.0000   -0.0001   -0.0002   -0.0000   -0.0005   -0.0000    0.0000
%    -0.0436   -0.0012    0.0012   -0.0110   -0.0138   -0.0009   -0.0293   -0.0010   -0.0023
%    -0.0000    0.0000    0.0000    0.0000   -0.0001    0.0000   -0.0000    0.0000    0.0000
%     0.0000   -0.0000   -0.0000    0.0000    0.0000   -0.0000    0.0000   -0.0000   -0.0000
%     0.9058    0.8934    0.3558    0.8325    0.7816    0.8271    0.8102    0.7149    0.9445
%    10.7399    7.8141    4.5868   17.3567   29.8341    9.3199   23.6763    1.6053    7.6386

% %% [markdown]
% ### 第十二个模型 赵向阳 – 2013

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
    [result_12] = Function_ParameterSol12(Data); % 第12个模型参数计算结果
    rc_12=size(result_12);
    row_12=rc_12(1,1); % 第12个模型参数计算结果构成的列向量有几行
    for j=1:1:row_12
        RESULT(j,i)=result_12(j,1); % 将第12个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07+row_08+row_09+row_10+row_11,i)=result_12(j,1); % 将第12个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 10x9 double
%    50.3000   42.7000   42.7000   50.3000   50.3000   42.7000   42.7000   42.7000   50.3000
%    30.2000   30.9000   30.9000   30.2000   30.2000   30.9000   30.9000   30.9000   30.2000
%     3.2630    0.0840    0.7010    0.4920    0.6950    0.0710    1.2800    0.8810    0.2020
%     0.0955   -0.0647   -0.0628    0.2415    0.3153   -0.1024    0.2345   -0.0297    0.0028
%    -0.0253   -0.0270    0.0032   -0.0407   -0.0432   -0.0245   -0.0510   -0.0020   -0.0182
%     0.0001    0.0001   -0.0000    0.0003    0.0003    0.0001    0.0004    0.0000   -0.0001
%     0.0071    0.0159   -0.0021    0.0201    0.0133    0.0145    0.0332    0.0032   -0.0027
%    -0.0000   -0.0001    0.0000   -0.0002   -0.0001   -0.0001   -0.0004   -0.0000    0.0002
%     0.8936    0.9461    0.2664    0.8079    0.7129    0.8823    0.7762    0.7364    0.9350
%     9.4738    5.7179    4.8237   16.5814   25.4148    7.8693   19.4305    1.5957    7.2785

% %% [markdown]
% ### 第十三个模型 高禹 – 2019

% %%
 close all;clear all;clc; % 关闭图窗、清空变量、清除命令窗口内容
%% 导入基础数据data
cd("D:\桌面\毕设\材料\20221127-结题材料\03-源代码\01 - 高温高压钻井液性质预测模型")
data=csvread('data18.csv',1,0); % data存储不同温度、压力及相应流体参数，其中第一列为温度（℃），第二列为压力（MPa），其余为相应流体参数
n=size(data); % 数据（自变量+因变量）共多少行多少列
n_row=n(1,1); % 样本观测次数
n_col=n(1,2); % 自变量+因变量个数（因变量n_col-2个）

%% 模型参数计算
for i=1:1:n_col-2 % i代表列，也代表因变量
    Data=[data(:,1),data(:,2),data(:,i+2)]; % 温度、压力与第i个因变量构成的n_row×3矩阵
    [result_13] = Function_ParameterSol13(Data); % 第13个模型参数计算结果
    rc_13=size(result_13);
    row_13=rc_13(1,1); % 第13个模型参数计算结果构成的列向量有几行
    for j=1:1:row_13
        RESULT(j,i)=result_13(j,1); % 将第13个模型参数计算结果存储到RESULT中
%         RESULT(j+row_01+row_02+row_03+row_04+row_05+row_06+row_07+row_08+row_09+row_10+row_11+row_12,i)=result_13(j,1); % 将第13个模型参数计算结果存储到RESULT中
    end
    end
RESULT
% Out:
% RESULT = 10x9 double
%    50.3000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000   42.7000
%    30.2000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000   30.9000
%     3.2630    0.0840    0.7010    0.5840    0.6770    0.0710    1.2800    0.8810    0.1880
%     1.0982    0.9991    0.9659    1.2338    1.4104    0.9739    1.2127    0.9805    1.1342
%    -0.0296   -0.0411    0.0025   -0.0520   -0.0459   -0.0382   -0.0744   -0.0045   -0.0119
%     0.0074    0.0214   -0.0038    0.0295    0.0211    0.0190    0.0551    0.0053   -0.0121
%    -0.0715   -0.9224    0.2784   -1.6329   -1.1250   -0.7518   -3.5399   -0.3511    1.3081
%     0.8535    1.6151   -0.1502    2.2297    1.7242    1.4518    3.9709    0.3371   -0.5610
%     0.8817    0.9521    0.2718    0.7813    0.6680    0.8945    0.7576    0.7373    0.9258
%    10.1649    5.2058    4.7229   17.7727   28.4963    7.2909   20.2585    1.6069    8.1373
