# %% [markdown]
# # 开源数据平台

# %% [markdown]
# **开源数据平台**
#
# - [Building an End-to-End Open-Source Modern Data Platform | by Mahdi Karabiben | Towards Data Science](https://towardsdatascience.com/building-an-end-to-end-open-source-modern-data-platform-c906be2f31bd)
#     - 数据平台
#         - 存储 (Storage)
#             - MinIO
#             - Iceberg
#             - Hudi
#             - Delta Lake
#             - 文件系统 (File System)
#             - 对象存储 (Object-based Storage)
#             - 数据库 (Database)
#             - 数据仓库 (Data Warehouse)
#                 - Snowflake
#                 - BigQuery
#                 - Redshift
#         - 数据集成 (Data Integration)
#             - Airbyte
#             - Jitsu (event-driven)
#             - Segment (event-driven)
#             - Apache NiFi
#             - Airflow
#         - 数据转换 (Data Transformation)
#             - dbt
#             - Spark
#             -
#         - 数据移动 (Movement)
#             - ETL
#             - Reverse ETL
#             - 流式引擎 (Streaming Engine)
#             - 编排引擎 (Orchestration Engine)
#                 - Apache Airflow
#                 - Dagster
#         - 数据监控 (Data Monitoring) / Data Observability
#             - Soda SQL
#             - Prometheus
#             - Grafana
#         - 数据可视化 (Data Visualization)
#             - 报表 (Reporting)
#             - 商业智能 (Business Intelligence)
#             - Apache Superset
#             - Metabase
#             - Redash
#         - 元数据管理 (Metadata Management)
#             - Storing the metadata catalog on MySQL
#             - Maintaining the metadata index via Elasticsearch
#             - Running the OpenMetadata UI and API server
#         - 数据处理 (Data Processing)
#             - 查询引擎 (Query Engine)
#                 - Trino
#                 - Presto
#             - API
#                 - Spark DataFrame API
#                 - SparkSQL API
#         - 数据治理 (Data Governance)
#             - 认证 (Authentication)
#             - 审核 (Authorization)
#             - 数据分类 (Data Cataloging)
#             - 发现 (Discovery)
#                 - Apache Atlas
#                 - Collibra
#             - lineage
#             - quality
#             - governance
#         - 基础设施
#             - MiniIO
#             - Docker
#             - Spark
#             - Kubernetes
#             - Docker Compose
#             - Kubernetes Helm
#             - Databricks
#             - Fivetran
#             - Sigma
#             - PowerBI
#             - Tableau
#             - Looker
#             - Atlan
# - [open data architecture | Medium](https://medium.com/@DataEnthusiast/open-data-architecture-at-scale-on-cloud-part-1-3381b411533f)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/dc351994-72dc-40e0-9282-b81381062a52/Untitled.png)
#
# - [Open-Source Modern Data Stack: 5 Steps to Build (atlan.com)](https://atlan.com/open-source-modern-data-stack/)
# - [Introduction to Open Source Data Platform (ODP) - Acceldata Open-Source Data Platform](https://docs.acceldata.io/odp/documentation/ODP-introduction)
#
# ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/536bc46b-0179-4f80-a603-59f581839785/Untitled.png)
#
# | COMPONENTS |  |  | OS |  |
# | --- | --- | --- | --- | --- |
# | Service | Version | RHEL/CentOS 7 | RHEL 8/RL 8 | Ubuntu 18/20 |
# | Ambari | 2.7.6.0 | ✅ | ✅ | ✅ |
# | Druid | 27.0.0 | ✅ | ✅ | ✅ |
# | Hadoop | 3.2.3 | ✅ | ✅ | ✅ |
# | HBase | 2.4.11 | ✅ | ✅ | ✅ |
# | Hive | 3.1.4 (4.0.0-alpha1) | ✅ | ✅ | ✅ |
# | Httpfs (mpack) | 2.7.1 | ✅ | ✅ | ✅ |
# | Hue (mpack) | 4.10.0 | ✅ | ✅ | ✅ |
# | Impala (mpack) | 4.1.2 | ✅ | ✅ |  |
# | Infra Solr | 2.7.6.0 | ✅ | ✅ | ✅ |
# | Kafka | 2.8.2 | ✅ | ✅ | ✅ |
# | Knox | 1.6.1 | ✅ | ✅ | ✅ |
# | Nifi (mpack) | 1.23.2 | ✅ | ✅ | ✅ |
# | Nifi Registry (mpack) | 1.23.2 | ✅ | ✅ | ✅ |
# | Oozie | 5.2.1 | ✅ | ✅ | ✅ |
# | Phoenix | 5.1.3 | ✅ | ✅ | ✅ |
# | Ranger | 2.3.0 | ✅ | ✅ | ✅ |
# | Spark 2 | 2.4.8 | ✅ | ✅ | ✅ |
# | Spark 3 (mpack) | 3.2.2 | ✅ | ✅ | ✅ |
# | Sqoop | 1.4.8 | ✅ | ✅ | ✅ |
# | Tez | 0.10.1 | ✅ | ✅ | ✅ |
# | Zeppelin | 0.10.1 | ✅ | ✅ | ✅ |
# | Zookeeper | 3.5.10 | ✅ | ✅ | ✅ |
# | ODP-UTILS | 1.1.0.22 | ✅ | ✅ | ✅ |
#
# | Name | Status |
# | --- | --- |
# | Java | JDK 8 (Complete)
# JDK 11 (TBD) |
# | Azul JDK
# Azul Zulu | 8.70.0.23 |
#
# | Service | Version |
# | --- | --- |
# | MySQL | 5.7.x, 8.x |
# | PostgreSQL | 12.17, 15.5 |
# | MariaDB | 10.3, 10.11 |
# | OracleDB | 12c and above |
#
# - [The modular open source data platform - Stackable](https://stackable.tech/en/)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/0c9acec6-c8a9-47cd-9f4f-8a9da56cf73e/Untitled.png)
#
# - [The Modern Data Stack: Open-source Edition | Datafold](https://www.datafold.com/blog/the-modern-data-stack-open-source-edition)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/c6337d1e-44b1-48ac-886b-2c9d369a7c36/Untitled.png)
#
# - [Open Source and the Data Lakehouse: Apache Arrow, Apache Iceberg, Nessie and Dremio | Dremio](https://www.dremio.com/blog/open-source-and-the-data-lakehouse-apache-arrow-apache-iceberg-nessie-and-dremio/)
# - [Open Data Lakehouse: Architecture, Iceberg, Icehouse (starburst.io)](https://www.starburst.io/data-glossary/open-data-lakehouse/)
# - [What Is A Data Platform? And How To Build An Awesome One (montecarlodata.com)](https://www.montecarlodata.com/blog-what-is-a-data-platform-and-how-to-build-one/)
# - [Hand-Picked Tools for Building an Open-Source Data Platform | by Anjan Banerjee | HCLTech-Starschema Blog | Medium](https://medium.com/starschema-blog/building-an-open-source-data-platform-consider-these-tools-cc4743a79f86)
# - [Open Data Platform for Data Observability (acceldata.io)](https://www.acceldata.io/open-data-platform)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/d28d60f3-8db7-4d76-aadc-7e67f8f16504/Untitled.png)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/64894c7e-33ad-4b0e-b1b8-f611fc8dd1c5/Untitled.png)
#
# - [The Architect's Guide to the Modern Data Stack - The New Stack](https://thenewstack.io/the-architects-guide-to-the-modern-data-stack/)
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/e680a692-ff8c-49af-8be8-ff965ccc7430/5a3f1fdc-8294-4647-9c7a-843c5db3700d/Untitled.png)
#
# - [Home Page (opendatahub.io)](https://opendatahub.io/)
# - [Why You Need an AI Platform to Scale Generative AI (dataiku.com)](https://pages.dataiku.com/why-ai-platforms-generative-ai?utm_id=14310740159--135532156508--544456399157--open%20source%20data&utm_source=nam-adwords&utm_medium=paid-search&utm_campaign=CONTENT%20Why%20Enterprises%20Need%20DS,%20ML,%20AI%20Platforms&gad_source=1&gclid=CjwKCAjww_iwBhApEiwAuG6ccHv5smjLgJeAiQBTTZQASCGQycTj6m685nNC8-T7PLb4mMnyJ8H9BBoC5KgQAvD_BwE)
# - [Understanding the modern data stack, and why open-source matters | Estuary](https://estuary.dev/understanding-the-modern-data-stack-and-why-open-source-matters/)
# - [What I Learned From The Open Source Data Stack Conference 2021 — James Le (jameskle.com)](https://jameskle.com/writes/open-source-data-stack-2021)
